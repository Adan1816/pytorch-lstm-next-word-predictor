# %% [markdown]
# <a href="https://colab.research.google.com/github/Adan1816/pytorch-lstm-next-word-predictor/blob/main/pytorch_lstm_next_word_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
